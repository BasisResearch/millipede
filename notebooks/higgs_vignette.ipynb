# %% [markdown]
# # Higgs Vignette

# %%
import numpy as np
import pandas as pd
import gzip
from millipede import BernoulliLikelihoodVariableSelector

# %% [markdown]
# ## A toy Higgs analysis
#
# We consider a [publicly available dataset](https://archive.ics.uci.edu/ml/datasets/HIGGS#) of (simulated) Higgs production in particle collisions at a particle collider like the LHC.
# The Higgs is a fundamental particle that formers the cornerstone of the Standard Model of particle physics.
#
# From our point of view this is just a logistic regression dataset with 28 features. Let's see if we can figure out which features are most informative for differentiating background events from true Higgs production events. In other words let's do feature selection. We proceed as follows.

# %% [markdown]
# ## First we load our dataset
#
# Our dataset has 28 continuous-valued covariates (features) and one binary-valued response or outcome variable. The response is in the final column ('signal_event'), with 0 corresponding to background events and 1 corresponding to signal events (i.e. those with a Higgs boson). We've randomly subsampled the (large) dataset to have only 500 data points.

# %%
dataframe = pd.read_csv(gzip.GzipFile("./data/higgs.csv.gz", "rb"), index_col=0)
dataframe.head(5)
# Out:
#    lepton_pT  lepton_eta  lepton_phi  missing_energy_magnitude  \
# 0  -0.979380      0.7984   -0.419629                 -0.920256
# 1  -0.750671      0.1504    0.670497                 -0.957327
# 2  -0.731734      0.5164   -0.085668                 -0.937382
# 3  -0.517963      0.1520   -0.746267                 -0.947095
# 4  -0.842460     -0.4184    0.432682                 -0.834378
#
#    missing_energy_phi   jet1_pt  jet1_eta  jet1_phi  jet1_btag   jet2_pt  ...  \
# 0           -0.326625 -0.924768 -0.031182 -0.797841       -1.0 -0.890909  ...
# 1           -0.001578 -0.901614 -0.336001  0.309158        1.0 -0.841725  ...
# 2           -0.672873 -0.860470  0.138569 -0.933781        1.0 -0.889450  ...
# 3           -0.869415 -0.887704 -0.038853  0.214605        1.0 -0.715040  ...
# 4           -0.446632 -0.829899 -0.451059 -0.709019        1.0 -0.881156  ...
#
#    jet4_phi  jet4_btag      m_jj     m_jjj      m_lv     m_jlv      m_bb  \
# 0  0.077073        1.0 -0.937439 -0.891028 -0.681260 -0.856590 -0.901631
# 1  0.184998       -1.0 -0.674253 -0.661044 -0.682098 -0.831254 -0.802116
# 2 -0.245166       -1.0 -0.945057 -0.910480 -0.681382 -0.838173 -0.775481
# 3  0.640253       -1.0 -0.965931 -0.935671 -0.682011 -0.762698 -0.871967
# 4  0.794339       -1.0 -0.908299 -0.853577 -0.608219 -0.829275 -0.828440
#
#       m_wbb    m_wwbb  signal_event
# 0 -0.905623 -0.908678           0.0
# 1 -0.672779 -0.704905           1.0
# 2 -0.859885 -0.871721           0.0
# 3 -0.868329 -0.891515           1.0
# 4 -0.761596 -0.767367           0.0
#
# [5 rows x 29 columns]

# %%
dataframe['signal_event'].head(5)
# Out:
# 0    0.0
# 1    1.0
# 2    0.0
# 3    1.0
# 4    0.0
# Name: signal_event, dtype: float64

# %% [markdown]
# Note that our features are neither zero-centered nor normalized.
# Whether this kind of pre-processing should be done for your dataset is  something the user should carefully consider before running variable selection.

# %%
print("feature means:\n", dataframe.values[:, :-1].mean(0))
# Out:
# feature means:
#  [-0.7765034   0.01102799 -0.00126153 -0.82028793 -0.00250205 -0.7906202
#  -0.01492074  0.00432537 -0.132      -0.79316277  0.01515241 -0.00160644
#  -0.102      -0.82294913 -0.01040416  0.01243709 -0.186      -0.87339811
#  -0.02154715  0.02000418 -0.324      -0.92062007 -0.87853068 -0.65429262
#  -0.79536005 -0.83153345 -0.80078183 -0.78532627]

# %% [markdown]
# ## Next we create a VariableSelector object appropriate for our binary-valued responses

# %%
# Note that by default we make use of all features/covariates.
# If we want to exclude any features from consideration we should
# drop them from the dataframe using pandas.DataFrame.drop
selector = BernoulliLikelihoodVariableSelector(dataframe,      # pass in the data
                                               'signal_event', # indicate the column of responses
                                               S=1,            # specify the expected number of covariates included a priori
                                               )

# %% [markdown]
# ## Finally we run the MCMC algorithm to compute posterior inclusion probabilities (PIPs) and other posterior quantities of interest

# %%
# this should take less than 15 seconds to run on a reasonably fast laptop
selector.run(T=5000, T_burnin=1000, verbosity='bar', seed=0)
# Out:
#   0%|          | 0/6000 [00:00<?, ?it/s]

# %% [markdown]
# ## The results are available in the selector.summary DataFrame
#
# - It appears that m_bb is the most important feature. This is not surprising, since this quantity reconstructs the mass of the Higgs boson. In particular the Higgs mass appears as a distinct peak on top of a smooth continuum of m_bb values from the background events.
# - Note that the intercept term does not have a corresponding PIP, since it is always included in the model by assumption.

# %%
selector.summary.sort_values(by=['PIP'], ascending=False)
# Out:
#                                PIP  Coefficient  Coefficient StdDev  \
# m_bb                      0.948540    -5.908611            1.929967
# m_wwbb                    0.904235    -8.698346            4.107494
# m_wbb                     0.819471     8.352952            4.236343
# jet2_pt                   0.629456     2.202100            1.756765
# jet1_pt                   0.380623     1.350613            1.707770
# jet4_pt                   0.214269     0.767959            1.387868
# m_jjj                     0.115638     0.655927            2.068083
# missing_energy_magnitude  0.025588    -0.052868            0.345914
# m_jlv                     0.019716     0.076237            0.516262
# m_jj                      0.010686    -0.040688            0.511469
# m_lv                      0.008506     0.017848            0.233177
# lepton_pT                 0.007249    -0.010362            0.120818
# lepton_eta                0.006801    -0.002893            0.038642
# jet2_phi                  0.006220     0.003032            0.037020
# jet3_pt                   0.003535    -0.001183            0.052694
# jet1_eta                  0.001108    -0.000154            0.011526
# jet2_eta                  0.001094     0.000032            0.008112
# jet3_phi                  0.001051    -0.000120            0.005645
# jet3_eta                  0.001035    -0.000002            0.009716
# jet4_eta                  0.000918     0.000063            0.006931
# jet4_btag                 0.000792    -0.000109            0.005265
# lepton_phi                0.000720    -0.000053            0.004119
# jet1_phi                  0.000703     0.000070            0.004750
# jet4_phi                  0.000681     0.000038            0.003376
# missing_energy_phi        0.000628    -0.000009            0.005498
# jet3_btag                 0.000606    -0.000087            0.004476
# jet2_btag                 0.000597     0.000053            0.003291
# jet1_btag                 0.000456    -0.000009            0.002235
# Intercept                      NaN    -0.905879            2.239434
#
#                           Conditional Coefficient  \
# m_bb                                    -6.240037
# m_wwbb                                  -9.630761
# m_wbb                                   10.130489
# jet2_pt                                  3.466697
# jet1_pt                                  3.379943
# jet4_pt                                  2.977446
# m_jjj                                    6.229692
# missing_energy_magnitude                -2.043700
# m_jlv                                    2.758054
# m_jj                                    -2.621528
# m_lv                                     1.641764
# lepton_pT                               -1.200280
# lepton_eta                              -0.430907
# jet2_phi                                 0.393864
# jet3_pt                                 -0.430513
# jet1_eta                                -0.116863
# jet2_eta                                 0.032652
# jet3_phi                                -0.130046
# jet3_eta                                -0.001477
# jet4_eta                                 0.063778
# jet4_btag                               -0.135479
# lepton_phi                              -0.070667
# jet1_phi                                 0.121102
# jet4_phi                                 0.081013
# missing_energy_phi                      -0.012353
# jet3_btag                               -0.119391
# jet2_btag                                0.093568
# jet1_btag                               -0.019878
# Intercept                               -0.905879
#
#                           Conditional Coefficient StdDev
# m_bb                                            1.365868
# m_wwbb                                          3.114510
# m_wbb                                           1.938654
# jet2_pt                                         0.688888
# jet1_pt                                         0.662980
# jet4_pt                                         0.943046
# m_jjj                                           2.428537
# missing_energy_magnitude                        0.746257
# m_jlv                                           1.498525
# m_jj                                            3.176341
# m_lv                                            1.528182
# lepton_pT                                       0.512484
# lepton_eta                                      0.194765
# jet2_phi                                        0.155145
# jet3_pt                                         0.908453
# jet1_eta                                        0.294807
# jet2_eta                                        0.256542
# jet3_phi                                        0.132739
# jet3_eta                                        0.285446
# jet4_eta                                        0.210843
# jet4_btag                                       0.127023
# lepton_phi                                      0.132686
# jet1_phi                                        0.156601
# jet4_phi                                        0.133549
# missing_energy_phi                              0.202950
# jet3_btag                                       0.114939
# jet2_btag                                       0.102449
# jet1_btag                                       0.100602
# Intercept                                       2.239434

# %% [markdown]
# Some additional stats about the MCMC run are available in `selector.stats`:

# %%
selector.stats
# Out:
# {'Weight quantiles': '5/10/20/50/90/95:  3.59e-03  6.13e-02  2.78e-01  3.25e+00  3.75e+00  3.85e+00',
#  'Weight moments': 'mean/std/min/max:  2.38e+00  1.50e+00  7.29e-07  4.33e+00',
#  'Elapsed MCMC time': '7.2 seconds',
#  'Mean iteration time': '1.197 ms',
#  'Number of retained samples': 5000,
#  'Number of burn-in samples': 1000,
#  'Adapted xi value': '3.092',
#  'Polya-Gamma MH stats': 'Mean acc. prob.: 0.838  Accepted/Attempted: 1081/1291'}

# %% [markdown]
# ## `assumed_columns` usage
#
# Above we setup the variable selection algorithm so that it makes inclusion/exclusion decisions for each input feature. Here we show how `assumed_columns` can be used to specify that certain features are assumed to be part of the model a priori. Such features do not come with Posterior Inclusion Probabilities--they are always included in the model by assumption.

# %%
# Let's suppose we know a priori that m_bb and m_wwbb should be included.
assumed_columns = ['m_bb', 'm_wwbb']
selector = BernoulliLikelihoodVariableSelector(dataframe,      # pass in the data
                                               'signal_event', # indicate the column of responses
                                               assumed_columns=assumed_columns,
                                               S=1,            # specify the expected number of covariates included a priori
                                               )

selector.run(T=5000, T_burnin=1000, verbosity='bar', seed=0)
# Out:
#   0%|          | 0/6000 [00:00<?, ?it/s]

# %% [markdown]
# Note that the assumed features no longer have PIPs but their coefficients do still have corresponding posterior means.

# %%
selector.summary.sort_values(by=['PIP'], ascending=False)
# Out:
#                                PIP  Coefficient  Coefficient StdDev  \
# m_wbb                     0.919534     9.180376            3.268594
# jet2_pt                   0.656186     2.293109            1.762578
# jet1_pt                   0.392750     1.432847            1.766051
# jet4_pt                   0.222820     0.615635            1.286852
# m_jjj                     0.124178     0.664957            1.884320
# m_jlv                     0.020998     0.057223            0.423086
# missing_energy_magnitude  0.019685    -0.028415            0.225722
# m_jj                      0.013594    -0.010397            0.307830
# m_lv                      0.008979     0.011344            0.178468
# lepton_eta                0.007294    -0.004970            0.055642
# jet2_phi                  0.006991     0.001914            0.028048
# lepton_pT                 0.005515    -0.002663            0.046057
# jet3_pt                   0.003678    -0.000685            0.050782
# jet1_eta                  0.001202    -0.000115            0.010079
# jet2_eta                  0.001148     0.000067            0.011074
# jet3_phi                  0.001143    -0.000233            0.008997
# jet3_eta                  0.001120     0.000025            0.009722
# jet4_eta                  0.000998     0.000126            0.008964
# jet4_btag                 0.000793    -0.000087            0.004868
# lepton_phi                0.000772    -0.000081            0.005396
# jet1_phi                  0.000747     0.000042            0.004766
# jet4_phi                  0.000734     0.000053            0.004854
# missing_energy_phi        0.000678     0.000003            0.004396
# jet3_btag                 0.000640    -0.000054            0.003749
# jet2_btag                 0.000626     0.000062            0.003857
# jet1_btag                 0.000487    -0.000030            0.002825
# m_bb                           NaN    -6.185411            1.592263
# m_wwbb                         NaN    -9.456145            3.138257
# Intercept                      NaN    -1.005714            2.011168
#
#                           Conditional Coefficient  \
# m_wbb                                   10.055759
# jet2_pt                                  3.516783
# jet1_pt                                  3.487854
# jet4_pt                                  2.989569
# m_jjj                                    5.236585
# m_jlv                                    2.414002
# missing_energy_magnitude                -1.710972
# m_jj                                    -1.128935
# m_lv                                     1.422313
# lepton_eta                              -0.494477
# jet2_phi                                 0.344211
# lepton_pT                               -0.719656
# jet3_pt                                 -0.173348
# jet1_eta                                -0.092760
# jet2_eta                                 0.046331
# jet3_phi                                -0.190456
# jet3_eta                                 0.029243
# jet4_eta                                 0.124249
# jet4_btag                               -0.108526
# lepton_phi                              -0.117099
# jet1_phi                                 0.075582
# jet4_phi                                 0.061695
# missing_energy_phi                       0.004464
# jet3_btag                               -0.088145
# jet2_btag                                0.108046
# jet1_btag                               -0.064571
# m_bb                                    -6.185411
# m_wwbb                                  -9.456145
# Intercept                               -1.005714
#
#                           Conditional Coefficient StdDev
# m_wbb                                           1.702879
# jet2_pt                                         0.679047
# jet1_pt                                         0.651605
# jet4_pt                                         0.971884
# m_jjj                                           2.005493
# m_jlv                                           1.364576
# missing_energy_magnitude                        0.434811
# m_jj                                            3.004368
# m_lv                                            1.409503
# lepton_eta                                      0.256864
# jet2_phi                                        0.153780
# lepton_pT                                       0.239203
# jet3_pt                                         0.788943
# jet1_eta                                        0.271383
# jet2_eta                                        0.288281
# jet3_phi                                        0.172668
# jet3_eta                                        0.329858
# jet4_eta                                        0.252622
# jet4_btag                                       0.133151
# lepton_phi                                      0.168128
# jet1_phi                                        0.187782
# jet4_phi                                        0.154018
# missing_energy_phi                              0.161063
# jet3_btag                                       0.123831
# jet2_btag                                       0.118581
# jet1_btag                                       0.112956
# m_bb                                            1.592263
# m_wwbb                                          3.138257
# Intercept                                       2.011168
